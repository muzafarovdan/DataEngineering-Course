# %% [markdown]
# Трекинг всех классов:

# %%
import cv2
from ultralytics import YOLO
import random


def process_video_with_tracking(model, input_video_path, show_video=True, save_video=False, output_video_path="output_video.mp4"):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    if not cap.isOpened():
        raise Exception("Error: Could not open video file.")

    # Get input video frame rate and dimensions
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the output video writer
    if save_video:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="botsort.yaml")

        if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            ids = results[0].boxes.id.cpu().numpy().astype(int)

            for box, id in zip(boxes, ids):
                # Generate a random color for each object based on its ID
                random.seed(int(id))
                color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
                
                cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
                cv2.putText(
                    frame,
                    f"Id {id}",
                    (box[0], box[1]),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0, 255, 255),
                    2,
                )
        
        if save_video:
            out.write(frame)

        if show_video:
            frame = cv2.resize(frame, (0, 0), fx=0.75, fy=0.75)
            cv2.imshow("frame", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    # Release the input video capture and output video writer
    cap.release()
    if save_video:
        out.release()

    # Close all OpenCV windows
    cv2.destroyAllWindows()

# Example usage:
model = YOLO('runs/detect/train/weights/best.pt')
model.fuse()
process_video_with_tracking(model, "test.mp4", show_video=True, save_video=False, output_video_path="output_video.mp4")

# %% [markdown]
# Трекинг лишь на класс птица:

# %%
import cv2
from ultralytics import YOLO
import random


def draw_bounding_boxes_without_id(frame, results):
    boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
    classes = results[0].boxes.cls.cpu().numpy().astype(int)

    for box, clss in zip(boxes, classes):
        # Generate a random color for each object based on its ID
        if clss != 0:
            random.seed(int(clss)+8)
            color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
            
            cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
            cv2.putText(
                frame,
                f"{model.model.names[clss]}",
                (box[0], box[1]),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (50, 255, 50),
                2,
            )
    return frame


def process_video_with_tracking(model, input_video_path, show_video=True, save_video=False, output_video_path="output_video.mp4"):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    if not cap.isOpened():
        raise Exception("Error: Could not open video file.")

    # Get input video frame rate and dimensions
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the output video writer
    if save_video:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="bytetrack.yaml", classes=0)
        results_detect = model_detect.predict(frame, iou=0.4, conf=0.5, imgsz=608, verbose=False)
    
        if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            ids = results[0].boxes.id.cpu().numpy().astype(int)

            for box, id in zip(boxes, ids):
                # Generate a random color for each object based on its ID
                random.seed(int(id))
                color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
                
                cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
                cv2.putText(
                    frame,
                    f"Id {id}",
                    (box[0], box[1]),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.70,
                    (0, 255, 255),
                    2,
                )

        if results_detect[0].boxes != None:
            draw_bounding_boxes_without_id(frame, results_detect)
            
        
        if save_video:
            out.write(frame)

        if show_video:
            frame = cv2.resize(frame, (0, 0), fx=0.75, fy=0.75)
            cv2.imshow("frame", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    # Release the input video capture and output video writer
    cap.release()
    if save_video:
        out.release()

    # Close all OpenCV windows
    cv2.destroyAllWindows()
    return results_detect, results

# Example usage:
model = YOLO('runs/detect/train/weights/best.pt')
model_detect = YOLO('runs/detect/train/weights/best.pt')
model.fuse()
model_detect.fuse()
results_detect, results = process_video_with_tracking(model, "test.mp4", show_video=True, save_video=False, output_video_path="output_video.mp4")
# Out:
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# [ WARN:0@2.292] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2386) handleMessage OpenCV | GStreamer warning: your GStreamer installation is missing a required plugin
# [ WARN:0@2.292] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2402) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module uridecodebin0 reported: Your GStreamer installation is missing a plug-in.
# [ WARN:0@2.292] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (1356) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0@2.292] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module 3. Active learning/inference.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=98'>99</a> model.fuse()
#     <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=99'>100</a> model_detect.fuse()
# --> <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=100'>101</a> results_detect, results = process_video_with_tracking(model, "test.mp4", show_video=True, save_video=False, output_video_path="output_video.mp4")
#
# /Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module 3. Active learning/inference.ipynb Cell 4 line 5
#      <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=47'>48</a> if not ret:
#      <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=48'>49</a>     break
# ---> <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=49'>50</a> results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="bytetrack.yaml", classes=0)
#      <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=50'>51</a> results_detect = model_detect.predict(frame, iou=0.4, conf=0.5, imgsz=608, verbose=False)
#      <a href='vscode-notebook-cell:/Users/muzafarov/Desktop/MyEducation/DataEngineering-Course/Module%203.%20Active%20learning/inference.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a> if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/engine/model.py:259, in Model.track(self, source, stream, persist, **kwargs)
#     257 kwargs['conf'] = kwargs.get('conf') or 0.1  # ByteTrack-based method needs low confidence predictions as input
#     258 kwargs['mode'] = 'track'
# --> 259 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/engine/model.py:239, in Model.predict(self, source, stream, predictor, **kwargs)
#     237 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     238     self.predictor.set_prompts(prompts)
# --> 239 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/engine/predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# --> 198     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/engine/predictor.py:265, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     263 # Inference
#     264 with profilers[1]:
# --> 265     preds = self.inference(im, *args, **kwargs)
#     267 # Postprocess
#     268 with profilers[2]:
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/engine/predictor.py:137, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     136                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 137 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:347, in AutoBackend.forward(self, im, augment, visualize)
#     344     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     346 if self.pt or self.nn_module:  # PyTorch
# --> 347     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     348 elif self.jit:  # TorchScript
#     349     y = self.model(im)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:203, in C2f.forward(self, x)
#     201 """Forward pass through C2f layer."""
#     202 y = list(self.cv1(x).chunk(2, 1))
# --> 203 y.extend(m(y[-1]) for m in self.m)
#     204 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:203, in <genexpr>(.0)
#     201 """Forward pass through C2f layer."""
#     202 y = list(self.cv1(x).chunk(2, 1))
# --> 203 y.extend(m(y[-1]) for m in self.m)
#     204 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:311, in Bottleneck.forward(self, x)
#     309 def forward(self, x):
#     310     """'forward()' applies the YOLO FPN to input data."""
# --> 311     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:40, in Conv.forward_fuse(self, x)
#      38 def forward_fuse(self, x):
#      39     """Perform transposed convolution of 2D data."""
# ---> 40     return self.act(self.conv(x))
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/DataEng/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
